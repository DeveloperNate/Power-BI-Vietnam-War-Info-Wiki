# %%
import pandas as pd
from pandas.io.html import read_html
import re


def year(row): 
    """ iterates through the rows.If row has a year, returns year and updates the current year. If not, return the current year  """
    global current_year
    regexp = re.compile(r'\s(\d{4})$')
    if regexp.search(row):
        current_year = re.search(regexp, row).groups()[0]
        return current_year
    else :
        return current_year
    
def month(row):
    """ iterates through the rows.If row has a 3 char string i.e Jan, returns that string. If not, return the Jan """
    regexp = re.compile(r'(\w{3})')
    if regexp.search(row):
        current_month = re.search(regexp, row).groups()[0]
        return current_month
    else: 
        return "Jan"

def day(row):
    """ iterates through the rows.If row has a 2 digit, returns that string. If not, returns 1 """
    regexp = re.compile(r'(\d{2})')
    if regexp.search(row):
        current_day = re.search(regexp, row).groups()[0]
        return current_day
    else: 
        return "1"

def region(row):
    regexp = re.compile(r'.*PROVINCE.*')
    if regexp.search(row):
        return row
    
def city(row):
    regexp = re.compile(r'.*CITY|VILLAGE|SAIGON|HUẾ.*')
    if regexp.search(row):
        return row
    


# put wiki table into dataframe,rename columns, normalise Location data, change Year,Month,Day into Datetime column, reduce dataframe to date + Location dataframe

page = 'https://en.wikipedia.org/wiki/List_of_allied_military_operations_of_the_Vietnam_War_(1968)'
wikitables = pd.read_html(page, index_col=0, attrs={"class":"wikitable"}, skiprows=1)
df = wikitables[0]
df.columns = ["Operation","Description","Location","VC_KIA","Allied_KIA"]

df.index = df.index.rename("Date")
df = df.reset_index()
df["Location"] = df["Location"].str.upper()
current_year = "1968"
df["Year"] = df["Date"].apply(lambda x: year(x))
df["Month"] = df["Date"].apply(lambda x: month(x))
df["Day"] = df["Date"].apply(lambda x: day(x))
months = {"Jan" : "01" ,"Feb":"02","Mar":"03","Apr":"04","May":"05","Jun":"06","Jul":"07","Aug" :"08","Sep":"09","Oct":"10","Nov":"11","Dec":"12"}
df["Month"] = df["Month"].map(months)
df["Day"] = df["Day"].apply(lambda x: "01" if int(x) > 28 else x )
df['Date'] = df.apply(lambda x:datetime.strptime("{0} {1} {2}".format(x['Year'],x['Month'], x['Day']), "%Y %m %d")
                     ,axis=1)

df = df[["Date","Location","Description","VC_KIA","Allied_KIA"]]

df["Location"] = df["Location"].str.replace("SOUTH|EAST|NORTH|WEST|[0-9]|KM |VICINITY| OF |BETWEEN| IN |AROUND|CENTRAL ","")
df["Location"] = df["Location"].fillna("VIETNAM")
df["Region"] = df["Location"].apply(lambda x: region(x))
df["City"] = df["Location"].apply(lambda x: city(x))

print(df)
# Out:
#           Date                                           Location  \
# 0   1968-01-01  "PARROT'S BEAK" AREA SVAY RIENG PROVINCE, CAMB...
# 1   1968-01-01                                            VIETNAM
# 2   1968-01-01                                            VIETNAM
# 3   1968-01-01                                            VIETNAM
# 4   1973-01-19                                  HO CHI MINH TRAIL
# 5   1973-01-19                                            I CORPS
# 6   1973-01-25                                   KON TUM PROVINCE
# 7   1973-01-01                               KHE SANH COMBAT BASE
# 8   1973-01-10                                 PHƯỚC TUY PROVINCE
# 9   1973-01-11                                  BIÊN HÒA PROVINCE
# 10  1973-01-13                                  BIÊN HÒA PROVINCE
# 11  1973-01-13                     GIA ĐỊNH AND LONG AN PROVINCES
# 12  1973-01-14                                           IV CORPS
# 13  1973-01-15                 QUANG DUC AND PHƯỚC LONG PROVINCES
# 14  1969-01-16                            AN KHÊ, PLEIKU PROVINCE
# 15  1969-01-18  BA XUYEN, DINH TUONG, KIEN HOA, PHUOC DINH AND...
# 16  1969-01-20                                 QUẢNG TRỊ PROVINCE
# 17  1969-01-20                                 BÌNH LONG PROVINCE
# 18  1969-01-20                                BÌNH THUẬN PROVINCE
# 19  1969-01-21                                                HUẾ
# 20  1969-01-21                                 QUẢNG TRỊ PROVINCE
# 21  1969-01-21                                   CAM LO AND CA LU
# 22  1969-01-22                 BÌNH ĐỊNH AND QUẢNG NGÃI PROVINCES
# 23  1969-01-22                                 QUẢNG TRỊ PROVINCE
# 24  1969-01-24                   BIÊN HÒA AND PHƯỚC TUY PROVINCES
# 25  1969-01-01                                     CUA VIET RIVER
# 26  1969-01-01                                  BIÊN HÒA PROVINCE
# 27  1969-02-01                                                HUẾ
# 28  1969-02-10                  BIÊN HÒA AND BÌNH DƯƠNG PROVINCES
# 29  1969-02-17                                             SAIGON
# ..         ...                                                ...
# 164 1969-10-28                                            VIETNAM
# 165 1969-11-01                                            VIETNAM
# 166 1969-11-01                                 KIEN GANG PROVINCE
# 167 1969-11-15                                     QUẢNG TRỊ CITY
# 168 1969-11-28                SONG RE VALLEY, QUẢNG NGÃI PROVINCE
# 169 1969-11-13                                 QUẢNG NAM PROVINCE
# 170 1972-11-15                                           ERN LAOS
# 171 1969-11-16                                 BÌNH LONG PROVINCE
# 172 1969-11-20                                            DA NANG
# 173 1969-11-20                               DINH TRUONG PROVINCE
# 174 1969-11-24                                 HẬU NGHĨA PROVINCE
# 175 1969-11-28                       KHE SANH, QUẢNG TRỊ PROVINCE
# 176 1969-12-01                                          VĨNH LONG
# 177 1969-12-28                                 QUẢNG TRỊ PROVINCE
# 178 1969-12-11                   KIEN HOA AND VĨNH BÌNH PROVINCES
# 179 1969-12-17                                  BIÊN HÒA PROVINCE
# 180 1969-12-01                                            VIETNAM
# 181 1969-12-19                                       AN HOA BASIN
# 182 1969-12-10                                 QUẢNG NAM PROVINCE
# 183 1969-12-28                                 QUẢNG TRỊ PROVINCE
# 184 1969-12-10                AN NHUT VILLAGE, PHƯỚC TUY PROVINCE
# 185 1969-12-11                                THỪA THIÊN PROVINCE
# 186 1969-12-15         BARRIER ISLAND, HỘI AN, QUẢNG NAM PROVINCE
# 187 1969-12-15                                 HẬU NGHĨA PROVINCE
# 188 1969-12-15                                 QUẢNG NAM PROVINCE
# 189 1969-12-16                                THỪA THIÊN PROVINCE
# 190 1969-12-18                                  TÂY NINH PROVINCE
# 191 1969-12-27                                 PHƯỚC TUY PROVINCE
# 192 1969-12-01                                 HẬU NGHĨA PROVINCE
# 193 1969-12-01                           HUẾ, THỪA THIÊN PROVINCE
#
#                                            Description   VC_KIA  \
# 0           USAF operation to sow anti-personnel mines      NaN
# 1    Systematic canvassing of the opinions of senio...      NaN
# 2    Nixon administration covert plan to coerce the...      NaN
# 3    USAF operation to start fires by dropping bulk...      NaN
# 4    USAF electronic warfare program to interdict t...      NaN
# 5    US Navy operation to interdict enemy bases and...      NaN
# 6               Special Forces Project DELTA operation      NaN
# 7                                         USAF bombing  unknown
# 8    2nd Battalion, Royal Australian Regiment, 7th ...      NaN
# 9    1st Brigade, 9th Infantry Division search and ...      NaN
# 10   199th Infantry Brigade search and destroy oper...      NaN
# 11   198th Infantry Brigade search and destroy oper...      NaN
# 12     1st Battalion, 16th Infantry Regiment operation      NaN
# 13   1st Brigade, 101st Airborne Division search an...      NaN
# 14   3rd Battalion, 503rd Infantry Regiment 173rd A...      NaN
# 15   MRF 2nd Brigade, 9th Infantry Division and US ...      344
# 16   BLT 3rd Battalion, 1st Marines and HMM-165 sea...       10
# 17   1st Infantry Division, 2nd Brigade, 101st Airb...      NaN
# 18   173rd Airborne Brigade, 3rd Brigade, 506th Air...     1042
# 19   2nd Battalion, 4th Marines and 1st Battalion, ...        1
# 20   1st Battalion, 1st Marines and 1st Battalion, ...       24
# 21   1st Battalion, 1st Marines, 1st Battalion, 3rd...     1801
# 22     2/1 Cavalry and 4th Infantry Division operation      614
# 23   1st Cavalry Division and 1st and 2nd Brigades,...     3268
# 24   2nd Battalion, Royal Australian Regiment, 3rd ...      NaN
# 25   3rd Battalion, 1st Marines and 1st Amphibian T...      NaN
# 26   11th Armored Cavalry Regiment operation to def...      NaN
# 27   1st Marines and 5th Marines operation to drive...     5113
# 28   2nd Brigade, 1st Infantry Division and ARVN 5t...      NaN
# 29   ARVN 1st, 3rd, 6th, 8th and 11th Airborne Brig...      953
# ..                                                 ...      ...
# 164  Redeployment of the 1st Cavalry Division to II...      NaN
# 165  3rd Marine Division, 1st Brigade, 5th Infantry...      NaN
# 166  US and Vietnamese Navy operation to interdict ...      219
# 167  1st Cavalry Division, 1st Brigade, 5th Infantr...      NaN
# 168                    11th Infantry Brigade operation      455
# 169  1st Battalion, 13th Marines and 1st and 3rd Ba...      NaN
# 170  USAF, US Navy, USMC and Royal Lao Air Force dr...      NaN
# 171  2/1 Cavalry, 3/1 Cavalry, 1st Squadron, 11th A...     2898
# 172  1st Battalion, 1st Marines, 2nd Battalion, 1st...     1023
# 173  9th Infantry Division reconnaissance in force ...      NaN
# 174  2nd Brigade, 25th Infantry Division clear and ...      NaN
# 175  1st Battalion, 9th Marines, 2nd Battalion, 9th...      NaN
# 176  1/7 Cavalry operation in the 44th Special Tact...       30
# 177  198th Infantry Brigade clear and search operation      NaN
# 178  9th Infantry Division and ARVN 7th Division op...    10889
# 179  2nd Squadron SAS 9th Battalion, Royal Australi...      NaN
# 180  Third Sealords barrier established along the V...      NaN
# 181  1st Battalion, 3rd Marines, 3rd Battalion, 3rd...     1398
# 182                    ARVN 1st Ranger Group operation      695
# 183  1st Brigade, 5th Infantry Division clear and s...      NaN
# 184  9th Battalion, Royal Australian Regiment cordo...      NaN
# 185  2nd Brigade, 101st Airborne Division and ARVN ...      NaN
# 186  BLT 2nd Battalion, 26th Marines and HMM-362 cl...       33
# 187                     1st Cavalry Division operation      NaN
# 188  196th Infantry Brigade clear and search operation      322
# 189  3rd Brigade, 101st Airborne Division clear and...      NaN
# 190              US Army-VC prisoner release operation      NaN
# 191  9th Battalion, Royal Australian Regiment block...      NaN
# 192  2nd Brigade, 25th Infantry Division search and...      NaN
# 193  3rd Brigade, 101st Airborne Division reconnais...       12
#
#          Allied_KIA                                             Region  \
# 0               NaN  "PARROT'S BEAK" AREA SVAY RIENG PROVINCE, CAMB...
# 1               NaN                                               None
# 2               NaN                                               None
# 3               NaN                                               None
# 4               NaN                                               None
# 5               NaN                                               None
# 6               NaN                                   KON TUM PROVINCE
# 7               NaN                                               None
# 8               NaN                                 PHƯỚC TUY PROVINCE
# 9               NaN                                  BIÊN HÒA PROVINCE
# 10              NaN                                  BIÊN HÒA PROVINCE
# 11              NaN                     GIA ĐỊNH AND LONG AN PROVINCES
# 12              NaN                                               None
# 13              NaN                 QUANG DUC AND PHƯỚC LONG PROVINCES
# 14              NaN                            AN KHÊ, PLEIKU PROVINCE
# 15               23  BA XUYEN, DINH TUONG, KIEN HOA, PHUOC DINH AND...
# 16               12                                 QUẢNG TRỊ PROVINCE
# 17              NaN                                 BÌNH LONG PROVINCE
# 18              NaN                                BÌNH THUẬN PROVINCE
# 19              NaN                                               None
# 20                2                                 QUẢNG TRỊ PROVINCE
# 21              359                                               None
# 22              156                 BÌNH ĐỊNH AND QUẢNG NGÃI PROVINCES
# 23              294                                 QUẢNG TRỊ PROVINCE
# 24              NaN                   BIÊN HÒA AND PHƯỚC TUY PROVINCES
# 25              NaN                                               None
# 26              NaN                                  BIÊN HÒA PROVINCE
# 27              142                                               None
# 28              NaN                  BIÊN HÒA AND BÌNH DƯƠNG PROVINCES
# 29              NaN                                               None
# ..              ...                                                ...
# 164             NaN                                               None
# 165             NaN                                               None
# 166             NaN                                 KIEN GANG PROVINCE
# 167             NaN                                               None
# 168              35                SONG RE VALLEY, QUẢNG NGÃI PROVINCE
# 169             NaN                                 QUẢNG NAM PROVINCE
# 170             NaN                                               None
# 171             219                                 BÌNH LONG PROVINCE
# 172  108 US, 2 ARVN                                               None
# 173             NaN                               DINH TRUONG PROVINCE
# 174             NaN                                 HẬU NGHĨA PROVINCE
# 175             NaN                       KHE SANH, QUẢNG TRỊ PROVINCE
# 176              29                                               None
# 177             NaN                                 QUẢNG TRỊ PROVINCE
# 178              40                   KIEN HOA AND VĨNH BÌNH PROVINCES
# 179             NaN                                  BIÊN HÒA PROVINCE
# 180             NaN                                               None
# 181             151                                               None
# 182             NaN                                 QUẢNG NAM PROVINCE
# 183             NaN                                 QUẢNG TRỊ PROVINCE
# 184             NaN                AN NHUT VILLAGE, PHƯỚC TUY PROVINCE
# 185             NaN                                THỪA THIÊN PROVINCE
# 186               3         BARRIER ISLAND, HỘI AN, QUẢNG NAM PROVINCE
# 187             NaN                                 HẬU NGHĨA PROVINCE
# 188              72                                 QUẢNG NAM PROVINCE
# 189             NaN                                THỪA THIÊN PROVINCE
# 190             NaN                                  TÂY NINH PROVINCE
# 191             NaN                                 PHƯỚC TUY PROVINCE
# 192             NaN                                 HẬU NGHĨA PROVINCE
# 193             NaN                           HUẾ, THỪA THIÊN PROVINCE
#
#                                     City
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# 5                                   None
# 6                                   None
# 7                                   None
# 8                                   None
# 9                                   None
# 10                                  None
# 11                                  None
# 12                                  None
# 13                                  None
# 14                                  None
# 15                                  None
# 16                                  None
# 17                                  None
# 18                                  None
# 19                                   HUẾ
# 20                                  None
# 21                                  None
# 22                                  None
# 23                                  None
# 24                                  None
# 25                                  None
# 26                                  None
# 27                                   HUẾ
# 28                                  None
# 29                                SAIGON
# ..                                   ...
# 164                                 None
# 165                                 None
# 166                                 None
# 167                       QUẢNG TRỊ CITY
# 168                                 None
# 169                                 None
# 170                                 None
# 171                                 None
# 172                                 None
# 173                                 None
# 174                                 None
# 175                                 None
# 176                                 None
# 177                                 None
# 178                                 None
# 179                                 None
# 180                                 None
# 181                                 None
# 182                                 None
# 183                                 None
# 184  AN NHUT VILLAGE, PHƯỚC TUY PROVINCE
# 185                                 None
# 186                                 None
# 187                                 None
# 188                                 None
# 189                                 None
# 190                                 None
# 191                                 None
# 192                                 None
# 193             HUẾ, THỪA THIÊN PROVINCE
#
# [194 rows x 7 columns]
